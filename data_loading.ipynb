# %%
import json

# %%
def load_data(filename):
    with open(filename, "r") as f:
        data = json.load(f)
    return data

# %%
data = load_data("cleaned_data.json")

# %%
data
# Out:
# {'users': [{'id': 1, 'name': 'Amit', 'friends': [2, 3], 'liked_pages': [101]},
#   {'id': 2, 'name': 'Priya', 'friends': [1, 4], 'liked_pages': [102]},
#   {'id': 4, 'name': 'Sara', 'friends': [2], 'liked_pages': [104]},
#   {'id': 6, 'name': 'Rahul', 'friends': [1, 2], 'liked_pages': [101, 105]},
#   {'id': 7, 'name': 'Neha', 'friends': [2, 6], 'liked_pages': [102, 106]},
#   {'id': 9, 'name': 'Karan', 'friends': [6, 7], 'liked_pages': [103, 107]},
#   {'id': 10, 'name': 'Pooja', 'friends': [9, 7], 'liked_pages': [106, 108]},
#   {'id': 11, 'name': 'Riya', 'friends': [1, 10], 'liked_pages': [101, 108]},
#   {'id': 12, 'name': 'Arjun', 'friends': [11, 6], 'liked_pages': [105, 107]},
#   {'id': 13, 'name': 'Sneha', 'friends': [9, 10], 'liked_pages': [102, 108]},
#   {'id': 15, 'name': 'Vikas', 'friends': [12, 13], 'liked_pages': [105, 101]},
#   {'id': 16, 'name': 'Meera', 'friends': [10, 15], 'liked_pages': [107, 108]},
#   {'id': 17, 'name': 'Ankit', 'friends': [16, 6], 'liked_pages': [105, 103]},
#   {'id': 18, 'name': 'Nisha', 'friends': [17, 11], 'liked_pages': [101, 106]},
#   {'id': 19, 'name': 'Rohan', 'friends': [18, 15], 'liked_pages': [102, 107]},
#   {'id': 20, 'name': 'Simran', 'friends': [16, 19], 'liked_pages': [108]},
#   {'id': 21, 'name': 'Kabir', 'friends': [18, 20], 'liked_pages': [103, 105]},
#   {'id': 22, 'name': 'Isha', 'friends': [17, 21], 'liked_pages': [101, 104]},
#   {'id': 24, 'name': 'Yash', 'friends': [21, 22], 'liked_pages': [107, 106]}],
#  'pages': [{'id': 101, 'name': 'Python Developers'},
#   {'id': 102, 'name': 'Data Science Enthusiasts'},
#   {'id': 103, 'name': 'AI & ML Community'},
#   {'id': 104, 'name': 'Web Development'},
#   {'id': 105, 'name': 'Machine Learning Hub'},
#   {'id': 106, 'name': 'Java Programmers'},
#   {'id': 107, 'name': 'Cloud Computing'},
#   {'id': 108, 'name': 'Open Source Developers'}]}

# %%
type(data)
# Out:
# dict

# %%
def display_users(data):
    print("Users with their connections : ")
    for user in data['users']:
        print(f"ID:{user['id']} - {user['name']} is friends with : {user['friends']} and liked pages are {user['liked_pages']}")
    print("\n Pages Information")
    for page in data['pages']:
        print(f"{page['id']}: {page['name']}")

display_users(data)
# Out:
# Users with their connections :
# ID:1 - Amit is friends with : [2, 3] and liked pages are [101]
# ID:2 - Priya is friends with : [1, 4] and liked pages are [102]
# ID:4 - Sara is friends with : [2] and liked pages are [104]
# ID:6 - Rahul is friends with : [1, 2] and liked pages are [101, 105]
# ID:7 - Neha is friends with : [2, 6] and liked pages are [102, 106]
# ID:9 - Karan is friends with : [6, 7] and liked pages are [103, 107]
# ID:10 - Pooja is friends with : [9, 7] and liked pages are [106, 108]
# ID:11 - Riya is friends with : [1, 10] and liked pages are [101, 108]
# ID:12 - Arjun is friends with : [11, 6] and liked pages are [105, 107]
# ID:13 - Sneha is friends with : [9, 10] and liked pages are [102, 108]
# ID:15 - Vikas is friends with : [12, 13] and liked pages are [105, 101]
# ID:16 - Meera is friends with : [10, 15] and liked pages are [107, 108]
# ID:17 - Ankit is friends with : [16, 6] and liked pages are [105, 103]
# ID:18 - Nisha is friends with : [17, 11] and liked pages are [101, 106]
# ID:19 - Rohan is friends with : [18, 15] and liked pages are [102, 107]
# ID:20 - Simran is friends with : [16, 19] and liked pages are [108]
# ID:21 - Kabir is friends with : [18, 20] and liked pages are [103, 105]
# ID:22 - Isha is friends with : [17, 21] and liked pages are [101, 104]
# ID:24 - Yash is friends with : [21, 22] and liked pages are [107, 106]
#
#  Pages Information
# 101: Python Developers
# 102: Data Science Enthusiasts
# 103: AI & ML Community
# 104: Web Development
# 105: Machine Learning Hub
# 106: Java Programmers
# 107: Cloud Computing
# 108: Open Source Developers
